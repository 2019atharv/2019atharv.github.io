# %% [markdown]
# <a href="https://colab.research.google.com/github/2019atharv/2019atharv.github.io/blob/master/YOLOv4_16_March.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15514, done.
# remote: Total 15514 (delta 0), reused 0 (delta 0), pack-reused 15514
# Receiving objects: 100% (15514/15514), 14.16 MiB | 16.60 MiB/s, done.
# Resolving deltas: 100% (10413/10413), done.

# %%
# %cd darknet
#!make
# Out:
# [Errno 2] No such file or directory: 'darknet'
# /root

# %%
# !cp cfg/yolov3.cfg cfg/yolov3-train.cfg

# %%
# !echo -e 'license-plate' > data/obj.names

# !echo -e 'classes = 1\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolo-license-plates' > data/obj.data

# %% [markdown]
# **Extraction Tool -> Patool**

# %%
# !pip install patool
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 7.2 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
import patoolib

# %%
# !mkdir data/obj

# !unzip ../archive.zip -d data/obj
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/obj/archive/images/License (636).png
#   inflating: data/obj/__MACOSX/archive/images/._License (636).png
#   inflating: data/obj/archive/images/License (266).png
#   inflating: data/obj/__MACOSX/archive/images/._License (266).png
#   inflating: data/obj/archive/images/License (1117).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1117).png
#   inflating: data/obj/archive/images/License (1547).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1547).png
#   inflating: data/obj/archive/images/License (972).png
#   inflating: data/obj/__MACOSX/archive/images/._License (972).png
#   inflating: data/obj/archive/images/License (1750).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1750).png
#   inflating: data/obj/archive/images/License (1300).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1300).png
#   inflating: data/obj/archive/images/License (421).png
#   inflating: data/obj/__MACOSX/archive/images/._License (421).png
#   inflating: data/obj/archive/images/License (32).png
#   inflating: data/obj/__MACOSX/archive/images/._License (32).png
#   inflating: data/obj/archive/images/License (134).png
#   inflating: data/obj/__MACOSX/archive/images/._License (134).png
#   inflating: data/obj/archive/images/License (564).png
#   inflating: data/obj/__MACOSX/archive/images/._License (564).png
#   inflating: data/obj/archive/images/License (1615).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1615).png
#   inflating: data/obj/archive/images/License (837).png
#   inflating: data/obj/__MACOSX/archive/images/._License (837).png
#   inflating: data/obj/archive/images/License (1245).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1245).png
#   inflating: data/obj/archive/images/License (1496).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1496).png
#   inflating: data/obj/archive/images/00000232.jpg
#   inflating: data/obj/__MACOSX/archive/images/._00000232.jpg
#   inflating: data/obj/archive/images/License (1029).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1029).png
#   inflating: data/obj/archive/images/License (1183).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1183).png
#   inflating: data/obj/archive/images/License (1479).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1479).png
#   inflating: data/obj/archive/images/License (708).png
#   inflating: data/obj/__MACOSX/archive/images/._License (708).png
#   inflating: data/obj/archive/images/License (358).png
#   inflating: data/obj/__MACOSX/archive/images/._License (358).png
#   inflating: data/obj/archive/images/License (1880).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1880).png
#   inflating: data/obj/archive/images/License (65).png
#   inflating: data/obj/__MACOSX/archive/images/._License (65).png
#   inflating: data/obj/archive/images/License (476).png
#   inflating: data/obj/__MACOSX/archive/images/._License (476).png
#   inflating: data/obj/archive/images/License (1357).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1357).png
#   inflating: data/obj/archive/images/License (1707).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1707).png
#   inflating: data/obj/archive/images/License (925).png
#   inflating: data/obj/__MACOSX/archive/images/._License (925).png
#   inflating: data/obj/archive/images/License (1212).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1212).png
#   inflating: data/obj/archive/images/License (860).png
#   inflating: data/obj/__MACOSX/archive/images/._License (860).png
#   inflating: data/obj/archive/images/License (1642).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1642).png
#   inflating: data/obj/archive/images/License (533).png
#   inflating: data/obj/__MACOSX/archive/images/._License (533).png
#   inflating: data/obj/archive/images/License (163).png
#   inflating: data/obj/__MACOSX/archive/images/._License (163).png
#   inflating: data/obj/archive/images/License (499).png
#   inflating: data/obj/__MACOSX/archive/images/._License (499).png
#   inflating: data/obj/archive/images/License (1091).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1091).png
#   inflating: data/obj/archive/images/00000024.jpg
#   inflating: data/obj/__MACOSX/archive/images/._00000024.jpg
#   inflating: data/obj/archive/images/00000030.jpg
#   inflating: data/obj/__MACOSX/archive/images/._00000030.jpg
#   inflating: data/obj/archive/images/License (1838).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1838).png
#   inflating: data/obj/archive/images/00000018.jpg
#   inflating: data/obj/__MACOSX/archive/images/._00000018.jpg
#   inflating: data/obj/archive/images/License (1584).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1584).png
#   inflating: data/obj/archive/images/License (933).png
#   inflating: data/obj/__MACOSX/archive/images/._License (933).png
#   inflating: data/obj/archive/images/License (1711).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1711).png
#   inflating: data/obj/archive/images/00000193.jpg
#   inflating: data/obj/__MACOSX/archive/images/._00000193.jpg
#   inflating: data/obj/archive/images/License (1341).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1341).png
#   inflating: data/obj/archive/images/License (899).png
#   inflating: data/obj/__MACOSX/archive/images/._License (899).png
#   inflating: data/obj/archive/images/License (460).png
#   inflating: data/obj/__MACOSX/archive/images/._License (460).png
#   inflating: data/obj/archive/images/License (73).png
#   inflating: data/obj/__MACOSX/archive/images/._License (73).png
#   inflating: data/obj/archive/images/License (175).png
#   inflating: data/obj/__MACOSX/archive/images/._License (175).png
#   inflating: data/obj/archive/images/License (525).png
#   inflating: data/obj/__MACOSX/archive/images/._License (525).png
#   inflating: data/obj/archive/images/License (1654).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1654).png
#   inflating: data/obj/archive/images/License (876).png
#   inflating: data/obj/__MACOSX/archive/images/._License (876).png
#   inflating: data/obj/archive/images/License (1204).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1204).png
#   inflating: data/obj/archive/images/License (1087).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1087).png
#   inflating: data/obj/archive/images/License (1592).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1592).png
#   inflating: data/obj/archive/images/License (1068).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1068).png
#   inflating: data/obj/archive/images/License (1438).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1438).png
#   inflating: data/obj/archive/images/License (749).png
#   inflating: data/obj/__MACOSX/archive/images/._License (749).png
#   inflating: data/obj/archive/images/License (319).png
#   inflating: data/obj/__MACOSX/archive/images/._License (319).png
#   inflating: data/obj/archive/images/License (24).png
#   inflating: data/obj/__MACOSX/archive/images/._License (24).png
#   inflating: data/obj/archive/images/License (437).png
#   inflating: data/obj/__MACOSX/archive/images/._License (437).png
#   inflating: data/obj/archive/images/License (1316).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1316).png
#   inflating: data/obj/archive/images/License (1746).png
#   inflating: data/obj/__MACOSX/archive/images/._License (1746).png
#   inflating: data/obj/archive/images/License (964).png
#   inflating: data/obj/__MACOSX/archive/images/._License (964).png
#   inflating: data/obj/archive/images/License (1253).png
#   inflating: data/obj/__MACOSX/archive/images/._License (
txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1130).txt
#   inflating: data/obj/archive/labels/License (1425).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1425).txt
#   inflating: data/obj/archive/labels/License (1075).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1075).txt
#   inflating: data/obj/archive/labels/License (304).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (304).txt
#   inflating: data/obj/archive/labels/License (754).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (754).txt
#   inflating: data/obj/archive/labels/License (580).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (580).txt
#   inflating: data/obj/archive/labels/License (39).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (39).txt
#   inflating: data/obj/archive/labels/License (1167).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1167).txt
#   inflating: data/obj/archive/labels/License (1537).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1537).txt
#   inflating: data/obj/archive/labels/License (1864).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1864).txt
#   inflating: data/obj/archive/labels/License (646).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (646).txt
#   inflating: data/obj/archive/labels/00000043.txt
#   inflating: data/obj/__MACOSX/archive/labels/._00000043.txt
#   inflating: data/obj/archive/labels/License (216).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (216).txt
#   inflating: data/obj/archive/labels/License (703).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (703).txt
#   inflating: data/obj/archive/labels/License (353).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (353).txt
#   inflating: data/obj/archive/labels/License (1022).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1022).txt
#   inflating: data/obj/archive/labels/License (1188).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1188).txt
#   inflating: data/obj/archive/labels/License (1472).txt
#   inflating: data/obj/__MACOSX/archive/labels/._License (1472).txt

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2023-03-16 19:01:14--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  18.4MB/s    in 9.4s
#
# 2023-03-16 19:01:25 (16.5 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# MODEL Training

# %%
# !./darknet detector train data/obj.data cfg/yolov3-train.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.7.0, GPU count: 1
#  OpenCV version: 4.2.0
# yolov3-train
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     18       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  18 0.006 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     18       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  18 0.012 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     18       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  18 0.025 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.304
# avg_outputs = 516723
#  Allocate additional workspace_size = 149.82 MB
# Loading weights from darknet53.conv.74...
#  seen 64, trained: 0 K-images (0 Kilo-batches_64)
# Done! Loaded 75 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# Resizing, random_coef = 1.40
#
#  608 x 608
#  Create 6 permanent cpu-threads
#  Very small path to the image:
# Cannot load image                 counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image index_test = round(100 / split_pct)
#
#  Error in load_data_detection() - OpenCV
# Cannot load image #file_val = open("test.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image current_dir = "data/obj/images/*.JPG"
#
#  Error in load_data_detection() - OpenCV
# Cannot load image index_test = round(100 / split_pct)
#
#  Error in load_data_detection() - OpenCV
#  Very small path to the image:
#  Very small path to the image:
# Cannot load image         if counter == index_test:
# Cannot load image Cannot load image
#  Error in load_data_detection() - OpenCV
#                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image split_pct = 10;Cannot load image import numpy as np
#
#
# Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#                 counter = 1
# Cannot load image file_train = open("data/train.txt", "w")
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
# Cannot load image         if counter == index_test:
#
#  Error in load_data_detection() - OpenCV
#
# Cannot load image         if counter == index_test:
#
#  Error in load_data_detection() - OpenCV
# Cannot load image #file_val = open("test.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# import numpy as np
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image counter = 1
# Cannot load image file_train.close()
# Cannot load image file_train.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#                 counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image Cannot load image import glob
#                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image index_test = round(100 / split_pct)
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image split_pct = 10;
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import numpy as np
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image split_pct = 10;
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image split_pct = 10;
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         if counter == index_test:
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image #file_val = open("test.txt", "w")
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
#  Very small path to the image:
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image #file_val = open("test.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#  Very small path to the image:
#  Very small path to the image:
# Cannot load image import numpy as np
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
#  Very small path to the image:
#  Very small path to the image:
# Cannot load image counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image index_test = round(100 / split_pct)
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train.close()
#
# Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#                 counter = 1
#
# Cannot load image split_pct = 10; Error in load_data_detection() - OpenCV
# current_dir = "data/obj/images/*.JPG"
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image current_dir = "data/obj/images/*.JPG"
#
#  Error in load_data_detection() - OpenCV
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image #file_val = open("test.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image index_test = round(100 / split_pct)
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
# Cannot load image index_test = round(100 / split_pct)
# Cannot load image import numpy as np
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
# Cannot load image import numpy as np
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
# Cannot load image Cannot load image
#  Error in load_data_detection() - OpenCV
# Cannot load image import numpy as np
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
#                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#  Error in load_data_detection() - OpenCV
# Cannot load image split_pct = 10;
#
#  Error in load_data_detection() - OpenCV
# Cannot load image #file_val = open("test.txt", "w")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         else:
#
#  Error in load_data_detection() - OpenCV
# Cannot load image index_test = round(100 / split_pct)
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
#         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# Cannot load image current_dir = "data/obj/images/*.JPG"
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#  Error in load_data_detection() - OpenCV
# Cannot load image current_dir = "data/obj/images/*.JPG"
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         if counter == index_test:
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_val.close()
#
#  Error in load_data_detection() - OpenCV
#  try to allocate additional workspace_size = 160.87 MB
#  CUDA allocate done!
# Loaded: 0.000062 seconds
# Cannot load image  Very small path to the image:
# import glob
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image current_dir = "data/obj/images/*.JPG"
#
#         else:#file_val = open("test.txt", "w")   Error in load_data_detection() - OpenCV
# Cannot load image                 counter = 1
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# index_test = round(100 / split_pct)
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
# file_train = open("data/train.txt", "w")  counter = 1   Error in load_data_detection() - OpenCV
# Cannot load image counter = 1
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
#                 counter = counter + 1
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image counter = 1
#
#                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")                file_train.write(current_dir + "/" + title + '.jpg' + "\n") Error in load_data_detection() - OpenCV
# Cannot load image                 counter = 1
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# counter = 1
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
#                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")split_pct = 10; Error in load_data_detection() - OpenCV
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
# Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image file_train.close()
#
# counter = 1   Error in load_data_detection() - OpenCV
# Cannot load image                 counter = 1
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#         if counter == index_test:
#
# Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image         else:
#
# file_val.close() Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#         if counter == index_test:
#
# Cannot load image  Error in load_data_detection() - OpenCV
# file_val.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train.close()
#
#  Error in load_data_detection() - OpenCV
# Cannot load image         else:
#
#  Error in load_data_detection() - OpenCV
# Cannot load image split_pct = 10;
#
#  Error in load_data_detection() - OpenCV
# Cannot load image file_train.close()
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image import sys
#
#         title, ext = os.path.splitext(os.path.basename(pathAndFilename))file_val.close() Error in load_data_detection() - OpenCV
# Cannot load image counter = 1
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
#                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image import os
#
#                 counter = 1file_val.close() Error in load_data_detection() - OpenCV
# Cannot load image current_dir = "data/obj/images/*.JPG"
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
# import numpy as np
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image         else:
#
# file_val.close()import sys Error in load_data_detection() - OpenCV
# Cannot load image                 counter = counter + 1
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#
#  Error in load_data_detection() - OpenCV
#                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
# Cannot load image Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
# file_train = open("data/train.txt", "w")                  counter = 1 Error in load_data_detection() - OpenCV
#
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
# #file_val = open("test.txt", "w")
#
# Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image         title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
# import numpy as np Error in load_data_detection() - OpenCV
# Cannot load image                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
#                 file_val.write(current_dir + "/" + title + '.jpg' + "\n")
#
# Cannot load image  Error in load_data_detection() - OpenCV
# Cannot load image file_train = open("data/train.txt", "w")
#
# import os Error in load_data_detection() - OpenCV
# Cannot load image import glob
#
#
#  Error in load_data_detection() - OpenCV
# Cannot load image
#  Error in load_data_detection() - OpenCV
# import sys
#
# Cannot load image  Error in load_data_detection() - OpenCV
#         else:
#
#  Error in load_data_detection() - OpenCV
# Cannot load image for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.jpg")):
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV
# Cannot load image                 file_train.write(current_dir + "/" + title + '.jpg' + "\n")
#
#  Error in load_data_detection() - OpenCV

# %%
# !pwd
# Out:
# /content/darknet
